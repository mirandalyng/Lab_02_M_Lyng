# %% [markdown]
# # LAB 02

# %% [markdown]
# ### Sources used
# - https://github.com/AIgineerAB/python_course/blob/main/14_oop_inheritance/slides_OOP_fundamentals_inheritance.pdf
# - https://github.com/AIgineerAB/python_course/tree/main/14_oop_inheritance
# - https://docs.python.org/3/library/abc.html
# - https://www.geeksforgeeks.org/python/dunder-magic-methods-python/
# - https://medium.com/@techwithjulles/python-calculates-and-displays-the-area-and-perimeter-of-a-rectangle-fc9577f6a9bc
# - https://stackoverflow.com/questions/12262017/python-checking-if-coordinates-are-within-circle
# - Some chat gpt to explain and understand certain math analysis and structure - for exampla I asked it for this picture and explenation
#     - ![ChatGPT Image 27 okt. 2025 14_56_32.png](<attachment:ChatGPT Image 27 okt. 2025 14_56_32.png>)

# %% [markdown]
# <div style="max-width:66ch;">
#
# ### Operator overloading
#
# <table style="display:inline-block; text-align:left;">
#   <tr style="background-color: #174A7E; color: white;">
#     <th>Operator</th>
#     <th>Dunder Method</th>
#   </tr>
#   <tr>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">__add__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">-</td>
#     <td style="text-align: center;">__sub__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">*</td>
#     <td style="text-align: center;">__mul__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">/</td>
#     <td style="text-align: center;">__div__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">//</td>
#     <td style="text-align: center;">__floordiv__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">%</td>
#     <td style="text-align: center;">__mod__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">**</td>
#     <td style="text-align: center;">__pow__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;"><</td>
#     <td style="text-align: center;">__lt__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;"><=</td>
#     <td style="text-align: center;">__le__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">></td>
#     <td style="text-align: center;">__gt__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">>=</td>
#     <td style="text-align: center;">__ge__(self, other)</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">==</td>
#     <td style="text-align: center;">__eq__(self, other)</td>
#   </tr>
# </table>
#
# </div>

# %% [markdown]
# ### UML - task 1

# %% [markdown]
# ## Trying and testing the classes in Task 01

# %%
from circle import Circle
from rectangle import Rectangle
# Out:
# True
