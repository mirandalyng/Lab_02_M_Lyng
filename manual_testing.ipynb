# %% [markdown]
# # Manual Testing

# %% [markdown]
# ### Trying and testing the classes in Task 01

# %%
from circle import Circle
from rectangle import Rectangle
from cube import Cube
from sphere import Sphere

# %%
circle1 = Circle(x=0, y=0, radius=1) # unit circle
circle2 = Circle(x=1, y=1, radius=1)
rectangle = Rectangle(x=0, y=0, width=1, height=1)

# %%
rectangle
# Out:
# Rectangle(width = 1, height = 1, x = 0, y = 0)

# %%
print(rectangle)
# Out:
# Rectangle with width = 1, height= 1= 0 and y = 0, area = 1.00 and perimeter = 4.00

# %%
print(circle1 == circle2) # True
# Out:
# True

# %%
print(circle2 == rectangle) # False
# Out:
# False

# %%
circle1.translate(5, 3)
circle1
# Out:
# Circle(1, x = 5, y = 3)

# %%
circle1.translate("THREE", 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 circle1.translate("THREE", 5)
#
# File ~/Desktop/Data_engineer/GitHub_repos/Lab_02_M_Lyng/shape.py:113, in Shape.translate(self, dx, dy)
#     111 def translate(self,dx,dy):
#     112     if not all(isinstance(value, (int, float)) for value in (dx,dy)):
# --> 113         raise TypeError(f"Type must be int or float")
#     114     """
#     115     Adding values to the x-coordinate and y-coordinate
#     116     """
#     117     self.x += dx
#
# TypeError: Type must be int or float

# %%
circle3 = Circle(radius=3)

# %%
circle3 >= circle1 # True
# Out:
# True

# %%
circle3
# Out:
# Circle(3, x = 0, y = 0)

# %%
print(circle3)
# Out:
# Circle with radius: 3, and positions x = 0 and y = 0, area = 28.27 and perimeter = 18.85

# %%
circle4 = Circle(0,0,1)
circle4.is_unit_circle()
# Out:
# True

# %%
cube = Cube(1,2,3)
print(cube)
# Out:
# Cube with side lenght: 1, and positions x = 2 and y = 3, area = 6.00 and perimeter = 12.00 and volume = 1.00

# %%
sphere = Sphere(3,0,0)
sphere
# Out:
# Sphere(3, x = 0, y = 0)

# %%
sphere2 = Sphere(-1,2,2)
print(sphere2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sphere2 = Sphere(-1,2,2)
#       2 print(sphere2)
#
# File ~/Desktop/Data_engineer/GitHub_repos/Lab_02_M_Lyng/sphere.py:13, in Sphere.__init__(self, radius, x, y)
#      10         raise TypeError(f"Type must be int or float")
#      12 if radius < 0:
# ---> 13     raise ValueError(f"Radius must be a positive number, not {radius}")
#      15 if x < 0 or y < 0:
#      16     raise ValueError(f"Values must be positive integers")
#
# ValueError: Radius must be a positive number, not -1
