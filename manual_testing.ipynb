# %% [markdown]
# # Manual Testing

# %% [markdown]
# ### Trying and testing the classes in Task 01

# %%
from circle import Circle
from rectangle import Rectangle
from cube import Cube
from sphere import Sphere
import matplotlib.pyplot as plt
import matplotlib.patches as patches 
from Shape_2D_plotter import Shape2DPlotter
from Shape_3D_plotter import Shape3DPlotter

# %%
circle1 = Circle(x=0, y=0, radius=1) # unit circle
circle1
# Out:
# Circle(radius = 1, x = 0, y = 0)

# %%
circle2 = Circle(x=1, y=1, radius=1)

# %%
rectangle = Rectangle(x=0, y=0, width=1, height=1)

# %%
rectangle
# Out:
# Rectangle(width = 1, height = 1, x = 0, y = 0)

# %%
rectangle.is_unit_square()
# Out:
# True

# %%
print(rectangle)
# Out:
# Rectangle with width = 1, height= 1= 0 and y = 0, area = 1.00 and perimeter = 4.00

# %%
print(circle1 == circle2) # True
# Out:
# True

# %%
print(circle2 == rectangle) # False
# Out:
# False

# %%
circle1.translate(5, 3)
circle1
# Out:
# Circle(radius = 1, x = 5, y = 3)

# %%
circle1.translate("THREE", 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 circle1.translate("THREE", 5)
#
# File ~/Desktop/Data_engineer/GitHub_repos/Lab_02_M_Lyng/shape.py:109, in Shape.translate(self, dx, dy)
#     107 def translate(self,dx,dy):
#     108     if not all(isinstance(value, (int, float)) for value in (dx,dy)):
# --> 109         raise TypeError(f"Type must be int or float")
#     110     """
#     111     Adding values to the x-coordinate and y-coordinate
#     112     """
#     113     self.x += dx
#
# TypeError: Type must be int or float

# %%
circle3 = Circle(radius=3)

# %%
circle3 >= circle1 # True

# %%
circle3

# %%
print(circle3)

# %%
circle4 = Circle(0,0,1)
circle4.is_unit_circle()

# %%
circle1.translate(2,3)

print(circle1)

# %% [markdown]
# ### Trying and testing the classes in Task 02

# %%
cube = Cube(1,2,3)
print(cube)

# %%
sphere = Sphere(3,0,0)
sphere

# %%
sphere2 = Sphere(-1,2,2)
print(sphere2)

# %%
rec4 = Rectangle(x=0, y=0, width=1, height=1)
rec4

# %%
cube1 = Cube(3)
cube1

# %%
cube1.translate(2,2)
cube1

# %%
cube1.translate(3,3)
cube1

# %% [markdown]
# ### testing Plotting in 2D

# %%
r1 = Rectangle(x = 100, y = 200, height = 200, width = 100)
r2 = Rectangle(x = 400, y = 300, height = 100, width = 40)
r3 = Rectangle(x = 60, y = 100, height = 40, width = 300)


plotter = Shape2DPlotter()
plotter.plot([r1, r2, r3])

# %%
c1 = Circle(x = 100, y = 200, radius = 10)
c2 = Circle(x = 400, y = 300, radius = 70)
c3 = Circle(x = 60, y = 100, radius = 5)


plotter = Shape2DPlotter()
plotter.plot([c1, c2, c3])

# %%
c1 = Circle(x = 100, y = 200, radius = 10)
c2 = Circle(x = 400, y = 300, radius = 70)
c3 = Circle(x = 60, y = 100, radius = 5)

r1 = Rectangle(x = 100, y = 200, height = 200, width = 100)
r2 = Rectangle(x = 400, y = 300, height = 100, width = 40)
r3 = Rectangle(x = 60, y = 100, height = 40, width = 300)


plotter = Shape2DPlotter()
plotter.plot([c1, c2, c3, r1, r2, r3])
